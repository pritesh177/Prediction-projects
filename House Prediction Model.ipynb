# %% [markdown]
# # Reading Dataset using Pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# # Check for missing or null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# Plots for analyzing data

# %%
# %matplotlib inline
import matplotlib as plt

# %%
# Some Insights using heatmap
df.hist(bins=50,figsize=(20,15))
# Out:
# array([[<AxesSubplot: title={'center': 'CRIM'}>,
#         <AxesSubplot: title={'center': 'ZN'}>,
#         <AxesSubplot: title={'center': 'INDUS'}>,
#         <AxesSubplot: title={'center': 'CHAS'}>],
#        [<AxesSubplot: title={'center': 'NOX'}>,
#         <AxesSubplot: title={'center': 'RM'}>,
#         <AxesSubplot: title={'center': 'AGE'}>,
#         <AxesSubplot: title={'center': 'DIS'}>],
#        [<AxesSubplot: title={'center': 'RAD'}>,
#         <AxesSubplot: title={'center': 'TAX'}>,
#         <AxesSubplot: title={'center': 'PTRATIO'}>,
#         <AxesSubplot: title={'center': 'B'}>],
#        [<AxesSubplot: title={'center': 'LSTAT'}>,
#         <AxesSubplot: title={'center': 'MEDV'}>, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)

# %% [markdown]
# # Splitting in train test data

# %%
from sklearn.model_selection import train_test_split

# %%
train_data,test_data=train_test_split(df,test_size=0.2,random_state=42)
print(f" Rows in Train data set {len(train_data)}\n Rows in Test data set {len(test_data)}")
# Out:
#  Rows in Train data set 404
#  Rows in Test data set 102

# %% [markdown]
# # We want to make sure that CHAS is included as a feature in both sets

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)
for train_index,test_index in split.split(df,df['CHAS']):
    train_dataset=df.loc[train_index]
    test_dataset=df.loc[test_index]

# %%
len(train_dataset)
# Out:
# 404

# %%
len(test_dataset)
# Out:
# 102

# %%
train_dataset['CHAS'].value_counts()
# Out:
# 0    376
# 1     28
# Name: CHAS, dtype: int64

# %%
test_dataset['CHAS'].value_counts()
# Out:
# 0    95
# 1     7
# Name: CHAS, dtype: int64

# %%
df=train_dataset.copy()

# %% [markdown]
# # Correlation between features

# %%
correlation=df.corr()
correlation['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.679894
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %% [markdown]
# # comparing most relatable features

# %%
from pandas.plotting import scatter_matrix

# %%
attributes=['MEDV','RM','LSTAT','ZN']
scatter_matrix(df[attributes], figsize= (20,15))
# Out:
# array([[<AxesSubplot: xlabel='MEDV', ylabel='MEDV'>,
#         <AxesSubplot: xlabel='RM', ylabel='MEDV'>,
#         <AxesSubplot: xlabel='LSTAT', ylabel='MEDV'>,
#         <AxesSubplot: xlabel='ZN', ylabel='MEDV'>],
#        [<AxesSubplot: xlabel='MEDV', ylabel='RM'>,
#         <AxesSubplot: xlabel='RM', ylabel='RM'>,
#         <AxesSubplot: xlabel='LSTAT', ylabel='RM'>,
#         <AxesSubplot: xlabel='ZN', ylabel='RM'>],
#        [<AxesSubplot: xlabel='MEDV', ylabel='LSTAT'>,
#         <AxesSubplot: xlabel='RM', ylabel='LSTAT'>,
#         <AxesSubplot: xlabel='LSTAT', ylabel='LSTAT'>,
#         <AxesSubplot: xlabel='ZN', ylabel='LSTAT'>],
#        [<AxesSubplot: xlabel='MEDV', ylabel='ZN'>,
#         <AxesSubplot: xlabel='RM', ylabel='ZN'>,
#         <AxesSubplot: xlabel='LSTAT', ylabel='ZN'>,
#         <AxesSubplot: xlabel='ZN', ylabel='ZN'>]], dtype=object)

# %%
df.plot(kind='scatter',x='MEDV',y='RM',alpha=0.8)
# Out:
# <AxesSubplot: xlabel='MEDV', ylabel='RM'>

# %%
df=train_dataset.drop(['MEDV'],axis=1)
df_label=train_dataset['MEDV']

# %%
#df['TAXRM']=df['TAX']/df['RM']

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT
# 254     16.4  392.89   6.57
# 348     17.0  390.94   5.99
# 476     20.2  396.21  18.68
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
df2=scaler.fit_transform(df)

# %%
df2
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %%
df_label
# Out:
# 254    21.9
# 348    24.5
# 476    16.7
# 321    23.1
# 326    23.0
#        ...
# 155    15.6
# 423    13.4
# 98     43.8
# 455    14.1
# 216    23.3
# Name: MEDV, Length: 404, dtype: float64

# %% [markdown]
# # Using models for prediction

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
#linear=LinearRegression()
#linear=DecisionTreeRegressor()
linear=RandomForestRegressor()

# %%
linear.fit(df2,df_label)
# Out:
# RandomForestRegressor()

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 155  3.53501   0.0  19.58     1  0.871  6.152  82.6  1.7455    5  403
# 423  7.05042   0.0  18.10     0  0.614  6.103  85.1  2.0218   24  666
# 98   0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2  276
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
# 216  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5  276
#
#      PTRATIO       B  LSTAT
# 254     16.4  392.89   6.57
# 348     17.0  390.94   5.99
# 476     20.2  396.21  18.68
# ...

# %%
df2
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %%
some_data=df.iloc[:5]
some_label=df_label.iloc[:5]

# %%
prepared=scaler.fit_transform(some_data)

# %%
some_data.shape
# Out:
# (5, 13)

# %%
some_label
# Out:
# 254    21.9
# 348    24.5
# 476    16.7
# 321    23.1
# 326    23.0
# Name: MEDV, dtype: float64

# %%
linear.predict(prepared)
# Out:
# array([20.092, 32.664,  9.449, 21.609, 21.498])

# %%
list(some_label)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %% [markdown]
# # Evaluate model

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
house_predictions=linear.predict(df2)
lin_mse=mean_squared_error(df_label,house_predictions)
lin_rmse=np.sqrt(lin_mse)

# %%
lin_rmse
# Out:
# 1.254893037136418

# %%
lin_mse
# Out:
# 1.5747565346534635

# %% [markdown]
# # It seems that model has overfitted after use of Linear model and then decision tree to solve this  we use cross validation here

# %%
from sklearn.model_selection import cross_val_score

# %%
scores=cross_val_score(linear,df2,df_label,scoring='neg_mean_squared_error',cv=10)
rmse=np.sqrt(-scores)

# %%
rmse
# Out:
# array([2.80916576, 2.80793331, 4.45289535, 2.67073525, 3.34598151,
#        2.59059283, 4.85306109, 3.28915866, 2.95851868, 3.44474196])

# %%
def scores_ev(scores):
    print('scores: ',scores)
    print('mean: ',scores.mean())
    print('std: ',scores.std())

# %%
scores_ev(rmse)
# Out:
# scores:  [2.80916576 2.80793331 4.45289535 2.67073525 3.34598151 2.59059283
#  4.85306109 3.28915866 2.95851868 3.44474196]
# mean:  3.3222784398412424
# std:  0.7251396584966102

# %%
x_test=test_dataset.drop(['MEDV'],axis=1)
y_test=test_dataset['MEDV']

# %%
prepared_x=scaler.transform(x_test)

# %%
final_prediction=linear.predict(prepared_x)

# %%
final_mse=mean_squared_error(y_test,final_prediction)

# %%
final_rmse=np.sqrt(final_mse)

# %%
final_rmse
# Out:
# 7.065563182665298

# %%
final_prediction
# Out:
# array([24.847,  7.832, 28.191, 16.796, 21.525, 13.268, 21.056,  8.503,
#        33.385, 41.256, 15.627,  8.443, 30.614, 11.627, 20.113,  9.07 ,
#        34.397, 13.103, 21.465, 15.766, 16.044, 14.674, 19.413, 18.743,
#        17.017, 41.06 , 16.338, 44.164,  8.443, 41.748, 20.04 , 10.673,
#        31.117,  8.004, 14.397,  8.218, 32.008, 20.886, 21.597, 42.734,
#        19.788, 27.781, 12.613, 20.751, 14.852, 41.743, 42.881, 20.274,
#         9.859, 19.564, 16.591, 12.994, 21.249,  8.44 , 27.285, 40.531,
#        40.798, 32.906, 19.242, 19.671, 44.369,  7.673, 19.317, 31.271,
#         8.394, 40.473, 15.085,  9.673, 13.335, 40.075, 43.043, 26.429,
#        15.397, 18.592, 42.935, 12.023, 11.779, 18.777, 20.154, 19.55 ,
#        19.63 , 31.972,  8.6  , 21.357, 21.38 , 13.987,  8.526, 18.758,
#        30.538, 19.693, 14.019, 40.36 ,  8.443, 26.153,  8.985, 43.149,
#        17.465, 41.028,  9.383, 28.477, 14.659, 15.088])

# %%
y_test
# Out:
# 342    16.5
# 379    10.2
# 223    30.1
# 219    23.0
# 48     14.4
#        ...
# 88     23.6
# 466    19.0
# 52     25.0
# 121    20.3
# 218    21.5
# Name: MEDV, Length: 102, dtype: float64

# %%
prepared[0]
# Out:
# array([-0.54613254,  1.22474487, -0.72437731,  0.        , -1.24995952,
#        -1.56482553, -0.63315717,  1.28708093, -0.8260802 , -0.34670673,
#        -1.39707095, -0.77512458, -0.46346653])

# %%
features=[[-0.54613254,  1.22474487, -0.72437731,  0.        , -1.24995952,
       -1.56482553, -0.63315717,  1.28708093, -0.8260802 , -0.34670673,
       -1.39707095, -0.77512458, -0.46346653]]
linear.predict(features)
# Out:
# array([20.092])
